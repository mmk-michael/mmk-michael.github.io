# %%
import netzsch_tools as nt

file = r"C:\Users\mita3616\OneDrive - Stockholm University\Documents\.PhD\Quasicrystals\ASY - Au-Sn-Yb\ASY-00010\ExpDat_QC-ASY-00010.txt"
meta, columns, data = nt.read_netzsch_expdat_file(file)

# %%
import pandas as pd

df = pd.DataFrame(data=data, columns=columns)
df
# Out:
#         Temp./°C   Time/min     DSC/(uV/mg)      Mass/%  \
# 0       22.72900    0.00000        -2.36853   100.00000
# 1       22.73900    0.25000        -2.41787   100.39801
# 2       22.77900    0.50000        -2.42167   103.38308
# 3       22.87100    0.75000        -2.19013   108.85572
# 4       23.10700    1.00000        -1.81815   115.17413
# ...          ...        ...             ...         ...
# 1625    97.43901  406.25000       -23.02489  -122.23524
# 1626    96.34668  406.50000       -22.73062  -122.72787
# 1627    95.26469  406.75000       -22.45995  -123.22997
# 1628    94.18235  407.00000       -22.18397  -123.62352
# 1629    93.13051  407.25000       -21.93559  -124.07366
#
#      Gas Flow(purge2)/(ml/min) Gas Flow(protective)/(ml/min) Sensit./(uV/mW)  \
# 0                     40.00000                      40.00000         1.00000
# 1                     40.00000                      40.00000         1.00000
# 2                     40.00000                      40.00000         1.00000
# 3                     40.00000                      40.00000         1.00000
# 4                     40.00000                      40.00000         1.00000
# ...                        ...                           ...             ...
# 1625                  40.00000                      40.00000         1.00000
# 1626                  40.00000                      40.00000         1.00000
# 1627                  40.00000                      40.00000         1.00000
# 1628                  40.00000                      40.00000         1.00000
# 1629                  40.00000                      40.00000         1.00000
#
#      Segment
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 1625       7
# 1626       7
# 1627       7
# 1628       7
# 1629       7
#
# [1630 rows x 8 columns]

# %%
def format_segment_keys(meta):
    segment_labels = ['Initial T', 'Rate/Duration', 'Target T']
    for k in list(meta):
        if "SEG." in meta[k]:
            segment_values = [meta[k].split('/',1)[0], meta[k].split('/')[1].rsplit('/',1)[0], meta[k].split('/')[1].rsplit('/',1)[1]]
            segment = dict(zip(segment_labels, segment_values))

            I = int(meta[k]['Initial T'][:-2]) # Strips °C 
            R = meta[k]['Rate/Duration']
            T = int(meta[k]['Target T'][:-2])
            if T > I:
                segment['Type'] = 'Heating'
            elif T < I:
                segment['Type'] = 'Cooling'
            elif T == I:
                segment['Type'] = 'Isothermal'
            meta[k] = segment
    print(segment)
    return meta 

format_segment_keys(meta)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17324/3392408466.py in <module>
#      20     return meta_copy
#      21
# ---> 22 format_segment_keys(meta)
#
# ~\AppData\Local\Temp/ipykernel_17324/3392408466.py in format_segment_keys(meta)
#      17                 segment['Type'] = 'Isothermal'
#      18             meta_copy[k] = segment
# ---> 19     print(segment)
#      20     return meta_copy
#      21
#
# UnboundLocalError: local variable 'segment' referenced before assignment

# %%
segment_labels = ['Initial T', 'Rate/Duration', 'Target T']
for k in list(meta):
    if "SEG." in k:
        segment_values = [meta[k].split('/',1)[0], 
                          meta[k].split('/',1)[1].rsplit('/',1)[0], 
                          meta[k].split('/',1)[1].rsplit('/',1)[-1]]
        segment = dict(zip(segment_labels, segment_values))
        meta[k] = segment
        I = int(meta[k]['Initial T'][:-2]) # Strips °C 
        R = meta[k]['Rate/Duration']
        T = int(meta[k]['Target T'][:-2])
        if T > I:
            segment['Type'] = 'Heating'
        elif T < I:
            segment['Type'] = 'Cooling'
        elif T == I:
            segment['Type'] = 'Isothermal'
        meta[k] = segment

print(meta[k])

# %%
meta[k].split('/',1)[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17324/785008326.py in <module>
# ----> 1 meta[k].split('/',1)[0]
#
# AttributeError: 'dict' object has no attribute 'split'
